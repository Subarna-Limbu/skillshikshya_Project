# %%
n=100

# %%
print(n)
# Out:
# 100

# %%
4^2
# Out:
# 6

# %%
s=200

# %%
print(s)
# Out:
# 200

# %%
x=100

# %%
y=float(x)

# %%
y
# Out:
# 100.0

# %%
from math import factorial

# %%
math.factorial(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 math.factorial(4)
#
# NameError: name 'math' is not defined

# %%
factorial(4)
# Out:
# 24

# %%
sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sqrt(2)
#
# NameError: name 'sqrt' is not defined

# %%
from math import squareroot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from math import squareroot
#
# ImportError: cannot import name 'squareroot' from 'math' (unknown location)

# %%
from math import sqrt

# %%
sqrt(4)
# Out:
# 2.0

# %%
math.pie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 math.pie
#
# NameError: name 'math' is not defined

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
sqrt(5)
# Out:
# 2.23606797749979

# %%
from math import min
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from math import min
#
# ImportError: cannot import name 'min' from 'math' (unknown location)

# %%
from math import minimum
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from math import minimum
#
# ImportError: cannot import name 'minimum' from 'math' (unknown location)

# %%
import math

# %%
math.min(4,5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 math.min(4,5)
#
# AttributeError: module 'math' has no attribute 'min'

# %%
name ="Subarna"

# %%
last name='Limbu'
# Out:
#   Cell In[25], line 1
#     last name='Limbu'
#          ^
# SyntaxError: invalid syntax

# %%
last_name = 'Limbu'

# %%
essay =""" hello
world """

# %%
essay
# Out:
# ' hello\nworld '

# %%
essay.upper()
# Out:
# ' HELLO\nWORLD '

# %%
essay.stripe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 essay.stripe()
#
# AttributeError: 'str' object has no attribute 'stripe'

# %%
name.stripe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 name.stripe()
#
# AttributeError: 'str' object has no attribute 'stripe'

# %%
name.stripe(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 name.stripe(4)
#
# AttributeError: 'str' object has no attribute 'stripe'

# %%
name.strip()
# Out:
# 'Subarna'

# %%
name.strip(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 name.strip(3)
#
# TypeError: strip arg must be None or str

# %%
name.strip("S")
# Out:
# 'ubarna'

# %%
name.strip("b")
# Out:
# 'Subarna'

# %%
name.strip("a")
# Out:
# 'Subarn'

# %%
email = "subarna@gmail.com"

# %%
provider = email.split('@')[-1].split('.')[0]

# %%
provider
# Out:
# 'gmail'

# %%
print("Gmail" if email.endswith("gmail.com") else "Not Gmail")
# Out:
# Gmail

# %%
if email.endswith("@gmail.com"):
     true
else:
 false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 if email.endswith("@gmail.com"):
# ----> 2      true
#       3 else:
#       4  false
#
# NameError: name 'true' is not defined

# %%
x="subarna@gmail.com"
if x.endswith("@gmail.com"):
    print("true")
else:
    print("false")
# Out:
# true

# %%
String
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 String
#
# NameError: name 'String' is not defined

# %%
len(name)
# Out:
# 7

# %%
name.index(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 name.index(2)
#
# TypeError: index() argument 1 must be str, not int

# %%
name.index("s")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 name.index("s")
#
# ValueError: substring not found

# %%
email.index("@",1,10)
# Out:
# 7

# %%
email{2:4:8}
# Out:
#   Cell In[72], line 1
#     email{2:4:8}
#          ^
# SyntaxError: invalid syntax

# %%
email[2:4:5]
# Out:
# 'b'

# %%
email[-1:-6:-7]
# Out:
# 'm'

# %%
email[-1:-6:-2]
# Out:
# 'mcl'

# %%
y="Subarna"

# %%
y[1:5:2]
# Out:
# 'ua'

# %%
y[1:5:1]
# Out:
# 'ubar'

# %%
y.index("a",0,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y.index("a",0,7)
#
# NameError: name 'y' is not defined

# %%
y[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y[0]
#
# NameError: name 'y' is not defined

# %%
y="Subarna"

# %%
y[0]
# Out:
# 'S'
